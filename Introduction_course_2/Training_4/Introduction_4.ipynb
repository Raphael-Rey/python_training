# %% [markdown]
# # Python training: some basics 4
# ## lxml introduction

# %%
from lxml import etree
from copy import deepcopy

# %%
# Always this way, to load data!
with open('BIBLIOGRAPHIC_51683500040005501_1.xml', 'r') as f:
    data = etree.parse(f, parser=etree.XMLParser(remove_blank_text=True))
xml = data.getroot()

# %%
print(etree.tostring(data, pretty_print=True).decode())
# Out:
# <collection>
#   <record>
#     <leader>01489nam a2200349 c 4500</leader>
#     <controlfield tag="001">991171012127005501</controlfield>
#     <controlfield tag="005">20230131165600.0</controlfield>
#     <controlfield tag="007">tu</controlfield>
#     <controlfield tag="008">220511s2023    gw ||||| |||| 00||||ger  </controlfield>
#     <datafield tag="015" ind1=" " ind2=" ">
#       <subfield code="a">22,N20</subfield>
#       <subfield code="2">dnb</subfield>
#     </datafield>
#     <datafield tag="016" ind1="7" ind2=" ">
#       <subfield code="2">DE-101</subfield>
#       <subfield code="a">125725149X</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9783446472310</subfield>
#       <subfield code="q">Print</subfield>
#       <subfield code="c">circa EUR 39.99 (DE), circa EUR 41.20 (AT)</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">3446472312</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(DE-101)125725149X</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(DE-599)DNB125725149X</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">DE-101</subfield>
#       <subfield code="b">ger</subfield>
#       <subfield code="c">DE-101</subfield>
#       <subfield code="d">CH-ZuSLS OSTGR E27</subfield>
#       <subfield code="d">CH-ZuSLS BFH E56</subfield>
#     </datafield>
#     <datafield tag="044" ind1=" " ind2=" ">
#       <subfield code="c">XA-DE-BY</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Freiknecht, Jonas</subfield>
#       <subfield code="d">1985-</subfield>
#       <subfield code="4">aut</subfield>
#       <subfield code="0">(DE-588)1026874556</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">KI-Sprachassistenten mit Python entwickeln</subfield>
#       <subfield code="b">Datenbewusst, open-source und modular</subfield>
#       <subfield code="c">Jonas Freiknecht</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Mu&#776;nchen</subfield>
#       <subfield code="b">Hanser</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">IX, 325 Seiten</subfield>
#       <subfield code="b">Illustrationen</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="504" ind1=" " ind2=" ">
#       <subfield code="a">Literaturverzeichnis Seite: 317-318. Stichwortverzeichnis Seite: 319-325.</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">KU&#776;NSTLICHE INTELLIGENZ</subfield>
#       <subfield code="9">ger</subfield>
#       <subfield code="0">(ETHUDK)000009085</subfield>
#       <subfield code="2">ethudk</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">AUTOMATISCHE SPRACHERKENNUNG (AKUSTIK)</subfield>
#       <subfield code="9">ger</subfield>
#       <subfield code="0">(ETHUDK)000014758</subfield>
#       <subfield code="2">ethudk</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">PYTHON (PROGRAMMIERSPRACHEN)</subfield>
#       <subfield code="0">(ETHUDK)000062602</subfield>
#       <subfield code="9">ger</subfield>
#       <subfield code="2">ethudk</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">MASCHINELLES LERNEN (KU&#776;NSTLICHE INTELLIGENZ)</subfield>
#       <subfield code="9">ger</subfield>
#       <subfield code="0">(ETHUDK)000038192</subfield>
#       <subfield code="2">ethudk</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">HUMAN-COMPUTER INTERACTION, HCI</subfield>
#       <subfield code="0">(ETHUDK)000053489</subfield>
#       <subfield code="9">ger</subfield>
#       <subfield code="2">ethudk</subfield>
#     </datafield>
#     <datafield tag="776" ind1="0" ind2="8">
#       <subfield code="i">Erscheint auch als</subfield>
#       <subfield code="n">Online-Ausgabe (e-book)</subfield>
#       <subfield code="z">9783446474482</subfield>
#     </datafield>
#     <datafield tag="776" ind1="0" ind2="8">
#       <subfield code="i">E-Pub</subfield>
#       <subfield code="z">9783446476592</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>00726nam a22002178c 4500</leader>
#     <controlfield tag="001">991171016129705501</controlfield>
#     <controlfield tag="005">20230208162215.0</controlfield>
#     <controlfield tag="008">220408t20232023gw a   | |||| 00||||ger  </controlfield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9783527719952</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">DE-101</subfield>
#       <subfield code="b">ger</subfield>
#       <subfield code="c">DE-101</subfield>
#       <subfield code="d">CH-ZuSLS BVERW BIG</subfield>
#       <subfield code="e">rda</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Ermel, Claudia</subfield>
#       <subfield code="4">aut</subfield>
#       <subfield code="0">(DE-588)114558914</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Programmieren und zeichnen mit Python fu&#776;r Dummies Junior</subfield>
#       <subfield code="c">Claudia Ermel, Olga Runge</subfield>
#     </datafield>
#     <datafield tag="250" ind1=" " ind2=" ">
#       <subfield code="a">2. Auflage 2023</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Weinheim</subfield>
#       <subfield code="b">Wiley-VCH</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">221 Seiten</subfield>
#       <subfield code="b">Illustrationen</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="490" ind1="0" ind2=" ">
#       <subfield code="a">... fu&#776;r Dummies</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Schlagwort</subfield>
#       <subfield code="2">gnd</subfield>
#     </datafield>
#     <datafield tag="700" ind1="1" ind2=" ">
#       <subfield code="a">Runge, Olga</subfield>
#       <subfield code="4">aut</subfield>
#       <subfield code="0">(DE-588)1138717282</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>01550nam a2200409 c 4500</leader>
#     <controlfield tag="001">991171021422205501</controlfield>
#     <controlfield tag="005">20230201101208.0</controlfield>
#     <controlfield tag="008">220307s2023    xxk           000 0 eng d</controlfield>
#     <datafield tag="015" ind1=" " ind2=" ">
#       <subfield code="a">GBC244409</subfield>
#       <subfield code="2">bnb</subfield>
#     </datafield>
#     <datafield tag="016" ind1="7" ind2=" ">
#       <subfield code="a">020518196</subfield>
#       <subfield code="2">Uk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9781292424125</subfield>
#       <subfield code="q">pbk.</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">1292424125</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(OCoLC)1308489142</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">UKMGB</subfield>
#       <subfield code="b">ger</subfield>
#       <subfield code="e">rda</subfield>
#       <subfield code="c">UKMGB</subfield>
#       <subfield code="d">OCLCO</subfield>
#       <subfield code="d">CH-ZuSLS UZB ZB</subfield>
#     </datafield>
#     <datafield tag="082" ind1="7" ind2="4">
#       <subfield code="a">004</subfield>
#       <subfield code="2">23sdnb</subfield>
#     </datafield>
#     <datafield tag="082" ind1="0" ind2="4">
#       <subfield code="a">005.133</subfield>
#       <subfield code="2">23</subfield>
#     </datafield>
#     <datafield tag="084" ind1=" " ind2=" ">
#       <subfield code="a">ST 250</subfield>
#       <subfield code="2">rvk</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Liang, Y. Daniel</subfield>
#       <subfield code="4">aut</subfield>
#       <subfield code="0">(DE-588)1235702677</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Introduction to Python programming and data structures</subfield>
#       <subfield code="c">Y. Daniel Liang</subfield>
#     </datafield>
#     <datafield tag="250" ind1=" " ind2=" ">
#       <subfield code="a">Third edition, global edition</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Harlow, United Kingdom</subfield>
#       <subfield code="b">Pearson</subfield>
#       <subfield code="c">[2023]</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">797 Seiten</subfield>
#       <subfield code="b">Illustrationen</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Python (Computer program language)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Object-oriented programming (Computer science)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="6">
#       <subfield code="a">Python (Langage de programmation)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="6">
#       <subfield code="a">Programmation oriente&#769;e objet (Informatique)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Object-oriented programming (Computer science)</subfield>
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst01042804</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Python (Computer program language)</subfield>
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst01084736</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Python</subfield>
#       <subfield code="g">Programmiersprache</subfield>
#       <subfield code="2">gnd</subfield>
#       <subfield code="0">(DE-588)4434275-5</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Objektorientierte Programmierung</subfield>
#       <subfield code="2">gnd</subfield>
#       <subfield code="0">(DE-588)4233947-9</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Datenstruktur</subfield>
#       <subfield code="2">gnd</subfield>
#       <subfield code="0">(DE-588)4011146-5</subfield>
#     </datafield>
#     <datafield tag="655" ind1=" " ind2="7">
#       <subfield code="a">Lehrbuch</subfield>
#       <subfield code="2">gnd-content</subfield>
#     </datafield>
#     <datafield tag="900" ind1=" " ind2=" ">
#       <subfield code="a">OK_GND</subfield>
#       <subfield code="x">UZB/Z01/202212/tschu</subfield>
#     </datafield>
#     <datafield tag="900" ind1=" " ind2=" ">
#       <subfield code="a">Stoppsignal FRED</subfield>
#       <subfield code="x">UZB/Z01/202212</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>02951nam a2200469 c 4500</leader>
#     <controlfield tag="001">991171033010205501</controlfield>
#     <controlfield tag="005">20230203114851.0</controlfield>
#     <controlfield tag="008">220324s2023    flu       f   001 0 eng  </controlfield>
#     <datafield tag="010" ind1=" " ind2=" ">
#       <subfield code="a">  2022004761</subfield>
#     </datafield>
#     <datafield tag="015" ind1=" " ind2=" ">
#       <subfield code="a">GBC2A2498</subfield>
#       <subfield code="2">bnb</subfield>
#     </datafield>
#     <datafield tag="016" ind1="7" ind2=" ">
#       <subfield code="a">020640930</subfield>
#       <subfield code="2">Uk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9780367687779</subfield>
#       <subfield code="q">hbk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">0367687771</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9780367687786</subfield>
#       <subfield code="q">pbk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">036768778X</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(OCoLC)1294287399</subfield>
#       <subfield code="z">(OCoLC)1294136308</subfield>
#       <subfield code="z">(OCoLC)1294219771</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">DLC</subfield>
#       <subfield code="b">ger</subfield>
#       <subfield code="c">DLC</subfield>
#       <subfield code="e">rda</subfield>
#       <subfield code="d">CH-ZuSLS UZB ZB</subfield>
#     </datafield>
#     <datafield tag="042" ind1=" " ind2=" ">
#       <subfield code="a">pcc</subfield>
#     </datafield>
#     <datafield tag="050" ind1="0" ind2="0">
#       <subfield code="a">QA76.73.P98</subfield>
#       <subfield code="b">H364 2022</subfield>
#     </datafield>
#     <datafield tag="082" ind1="0" ind2="0">
#       <subfield code="a">005.13/3</subfield>
#       <subfield code="2">23/eng/20220416</subfield>
#     </datafield>
#     <datafield tag="082" ind1="7" ind2="4">
#       <subfield code="a">004</subfield>
#       <subfield code="2">23sdnb</subfield>
#     </datafield>
#     <datafield tag="245" ind1="0" ind2="0">
#       <subfield code="a">Handbook of computer programming with Python</subfield>
#       <subfield code="c">edited by Dimitrios Xanthidis, Christos Manolas, Ourania K. Xanthidou, Han-I Wang</subfield>
#     </datafield>
#     <datafield tag="250" ind1=" " ind2=" ">
#       <subfield code="a">First edition</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Boca Raton</subfield>
#       <subfield code="b">CRC Press</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">x, 619 Seiten</subfield>
#       <subfield code="b">Illustrationen</subfield>
#       <subfield code="c">26 cm</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="500" ind1=" " ind2=" ">
#       <subfield code="a">"A Chapman &amp; Hall book"</subfield>
#     </datafield>
#     <datafield tag="504" ind1=" " ind2=" ">
#       <subfield code="a">Includes bibliographical references and index</subfield>
#     </datafield>
#     <datafield tag="520" ind1=" " ind2=" ">
#       <subfield code="a">"From geometric primitives to animation to 3D modeling to lighting, shading and texturing, Computer Graphics Through OpenGL&#174;: From Theory to Experiments is a comprehensive introduction to computer graphics which uses an active learning style to teach key concepts. Equally emphasizing theory and practice, the book provides an understanding not only of the principles of 3D computer graphics, but also the use of the OpenGL&#174; Application Programming Interface (API) to code 3D scenes and animation, including games and movies. The undergraduate core of the book takes the student from zero knowledge of computer graphics to a mastery of the fundamental concepts with the ability to code applications using fourth-generation OpenGL&#174;, as well as using WebGL&#174; in order to publish to the web. The remaining chapters explore more advanced topics, including the structure of curves and surfaces, applications of projective spaces and transformations and the implementation of graphics pipelines. This book can be used for introductory undergraduate computer graphics courses over one to two semesters. The careful exposition style attempting to explain each concept in the simplest terms possible should appeal to the self-study student as well."</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Python (Computer program language)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Computer programming</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="6">
#       <subfield code="a">Python (Langage de programmation)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="6">
#       <subfield code="a">Programmation (Informatique)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">computer programming</subfield>
#       <subfield code="2">aat</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Computer programming</subfield>
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst00872390</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Python (Computer program language)</subfield>
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst01084736</subfield>
#     </datafield>
#     <datafield tag="700" ind1="1" ind2=" ">
#       <subfield code="a">Xanthidis, Dimitrios</subfield>
#       <subfield code="4">edt</subfield>
#     </datafield>
#     <datafield tag="776" ind1="0" ind2="8">
#       <subfield code="i">Erscheint auch als</subfield>
#       <subfield code="n">Online-Ausgabe, EPUB</subfield>
#       <subfield code="z">9781000619867</subfield>
#     </datafield>
#     <datafield tag="776" ind1="0" ind2="8">
#       <subfield code="i">Erscheint auch als</subfield>
#       <subfield code="n">Online-Ausgabe, ebk</subfield>
#       <subfield code="z">9781003139010</subfield>
#     </datafield>
#     <datafield tag="776" ind1="0" ind2="8">
#       <subfield code="i">Erscheint auch als</subfield>
#       <subfield code="n">Online-Ausgabe, PDF</subfield>
#       <subfield code="z">9781000619553</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>01180nam a2200253 c 4500</leader>
#     <controlfield tag="001">991171056243005501</controlfield>
#     <controlfield tag="005">20221123150325.0</controlfield>
#     <controlfield tag="008">221101t2023    sz ||||      |00| ||eng d</controlfield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9783031137136</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">CH-ZuSLS HESSO HEIG-VD</subfield>
#       <subfield code="b">fre</subfield>
#       <subfield code="e">rda</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Taillard, &#201;ric</subfield>
#       <subfield code="d">19..-....</subfield>
#       <subfield code="0">(IDREF)192296515</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Design of heuristic algorithms for hard optimization</subfield>
#       <subfield code="b">with Python codes for the travelling salesman problem</subfield>
#       <subfield code="c">&#201;ric D. Taillard</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Cham</subfield>
#       <subfield code="b">Springer</subfield>
#       <subfield code="c">[2023]</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="4">
#       <subfield code="c">&#169;2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">XV, 287 pages</subfield>
#       <subfield code="b">illustrations</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="490" ind1="0" ind2=" ">
#       <subfield code="a">Graduate texts in operations research</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="2">ETHUDK</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">ME&#769;THODES HEURISTIQUES (RECHERCHE OPE&#769;RATIONNELLE)</subfield>
#       <subfield code="9">fre</subfield>
#       <subfield code="0">(ETHUDK)000048813</subfield>
#       <subfield code="2">ETHUDK</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">PROBLE&#768;MES COMBINATOIRES (OPTIMISATION DISCRE&#768;TE)</subfield>
#       <subfield code="9">fre</subfield>
#       <subfield code="0">(ETHUDK)000013865</subfield>
#       <subfield code="2">ETHUDK</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">ALGORITHMES EN THE&#769;ORIE DES GRAPHES + ALGORITHMES GE&#769;OME&#769;TRIQUES (THE&#769;ORIE DES GRAPHES)</subfield>
#       <subfield code="9">fre</subfield>
#       <subfield code="0">(ETHUDK)000047857</subfield>
#       <subfield code="2">ETHUDK</subfield>
#     </datafield>
#     <datafield tag="655" ind1=" " ind2="7">
#       <subfield code="a">[Manuels d'enseignement sup&#233;rieur]</subfield>
#       <subfield code="0">(RERO)A021035909</subfield>
#       <subfield code="2">rero</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>02314nam a22003738c 4500</leader>
#     <controlfield tag="001">991171104173205501</controlfield>
#     <controlfield tag="005">20221123084659.0</controlfield>
#     <controlfield tag="008">220708s2023    flu      b    001 0 eng  </controlfield>
#     <datafield tag="010" ind1=" " ind2=" ">
#       <subfield code="a">  2022026521</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9780367749361</subfield>
#       <subfield code="q">hbk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">036774936X</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9780367744519</subfield>
#       <subfield code="q">pbk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">0367744511</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(OCoLC)1348934576</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">DLC</subfield>
#       <subfield code="b">ger</subfield>
#       <subfield code="e">rda</subfield>
#       <subfield code="c">DLC</subfield>
#       <subfield code="d">CH-ZuSLS UZB ZB</subfield>
#     </datafield>
#     <datafield tag="042" ind1=" " ind2=" ">
#       <subfield code="a">pcc</subfield>
#     </datafield>
#     <datafield tag="050" ind1="0" ind2="0">
#       <subfield code="a">QA276.45.P98</subfield>
#       <subfield code="b">R64 2023</subfield>
#     </datafield>
#     <datafield tag="082" ind1="0" ind2="0">
#       <subfield code="a">519.50285/5133</subfield>
#       <subfield code="2">23/eng20221026</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Rogel-Salazar, Jesus</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Statistics and data visualisation with Python</subfield>
#       <subfield code="c">Dr. Jes&#250;s Rogel-Salazar</subfield>
#     </datafield>
#     <datafield tag="250" ind1=" " ind2=" ">
#       <subfield code="a">First edition</subfield>
#     </datafield>
#     <datafield tag="263" ind1=" " ind2=" ">
#       <subfield code="a">2212</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Boca Raton, FL</subfield>
#       <subfield code="b">CRC Press</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">Seiten</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="490" ind1="0" ind2=" ">
#       <subfield code="a">Chapman &amp; Hall/CRC Press the python series</subfield>
#     </datafield>
#     <datafield tag="504" ind1=" " ind2=" ">
#       <subfield code="a">Enth&#228;lt bibliografische Referenzen und Index</subfield>
#     </datafield>
#     <datafield tag="520" ind1=" " ind2=" ">
#       <subfield code="a">"This book is intended to serve as a bridge in statistics for graduates and business practitioners interested in using their skills in the area of data science and analytics as well as statistical analysis in general. On the one hand, the book is intended to be a refresher for readers that have taken some courses in statistics, but who have not necessarily used it in their day-to-day work. On the other hand, the material can be suitable for readers interested in the subject as a first encounter with statistical work in Python. Statistics and Data Visualisation with Python aims to build statistical knowledge from the ground up by enabling the reader to understand the ideas behind inferential statistics, and begin to formulate hypotheses that form the foundations for the applications and algorithms in statistical analysis, business analytics, machine learning and applied machine learning. This book begins with the basics of programming in Python and data analysis, to help construct a solid basis in statistical methods and hypothesis testing, which are useful in many modern applications"--</subfield>
#       <subfield code="c">Provided by publisher.</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Mathematical statistics</subfield>
#       <subfield code="x">Data processing</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Python (Computer program language)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Information visualization</subfield>
#     </datafield>
#     <datafield tag="776" ind1="0" ind2="8">
#       <subfield code="i">Erscheint auch als</subfield>
#       <subfield code="n">Online-Ausgabe (ebk)</subfield>
#       <subfield code="z">9781003160359</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>01050nam a22003138c 4500</leader>
#     <controlfield tag="001">991171105403405501</controlfield>
#     <controlfield tag="005">20221125230103.0</controlfield>
#     <controlfield tag="008">221020s2023    maua          001 0 eng d</controlfield>
#     <datafield tag="015" ind1=" " ind2=" ">
#       <subfield code="a">GBC2K0036</subfield>
#       <subfield code="2">bnb</subfield>
#     </datafield>
#     <datafield tag="016" ind1="7" ind2=" ">
#       <subfield code="a">020800866</subfield>
#       <subfield code="2">Uk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9781098111878</subfield>
#       <subfield code="q">pbk.</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">1098111877</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(OCoLC)1350640045</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">UKMGB</subfield>
#       <subfield code="b">ger</subfield>
#       <subfield code="e">rda</subfield>
#       <subfield code="c">UKMGB</subfield>
#       <subfield code="d">CH-ZuSLS UZB ZB</subfield>
#     </datafield>
#     <datafield tag="082" ind1="0" ind2="4">
#       <subfield code="a">001.4226</subfield>
#       <subfield code="2">23</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Dale, Kyran</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Data visualization with Python and JavaScript</subfield>
#       <subfield code="b">scrape, clean, explore &amp; transform your data</subfield>
#       <subfield code="c">Kyran Dale</subfield>
#     </datafield>
#     <datafield tag="250" ind1=" " ind2=" ">
#       <subfield code="a">Second edition</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Cambridge</subfield>
#       <subfield code="b">O'Reilly</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">553 Seiten</subfield>
#       <subfield code="b">illustrations (black and white, and colour)</subfield>
#       <subfield code="c">23 cm</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="a">text</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="a">still image</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="a">unmediated</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="a">volume</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="500" ind1=" " ind2=" ">
#       <subfield code="a">Previous edition: 2016</subfield>
#     </datafield>
#     <datafield tag="500" ind1=" " ind2=" ">
#       <subfield code="a">Includes index</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Information visualization</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Python (Computer program language)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">JavaScript (Computer program language)</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>00845nam a22002538c 4500</leader>
#     <controlfield tag="001">991171113493405501</controlfield>
#     <controlfield tag="005">20221209230040.0</controlfield>
#     <controlfield tag="008">221118s2023    gw     | |||| 00||||ger d</controlfield>
#     <datafield tag="015" ind1=" " ind2=" ">
#       <subfield code="a">22,N47</subfield>
#       <subfield code="2">dnb</subfield>
#     </datafield>
#     <datafield tag="016" ind1="7" ind2=" ">
#       <subfield code="2">DE-101</subfield>
#       <subfield code="a">1273086228</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9783836291293</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">3836291290</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(DE-101)1273086228</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(DE-599)DNB1273086228</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">DE-101</subfield>
#       <subfield code="b">ger</subfield>
#       <subfield code="c">DE-101</subfield>
#       <subfield code="d">CH-ZuSLS BVERW BIG</subfield>
#       <subfield code="e">rda</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Ernesti, Johannes</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Python 3</subfield>
#       <subfield code="b">Das umfassende Handbuch: U&#776;ber 1.000 Seiten Sprachgrundlagen, OOP und Beispielprogramme</subfield>
#       <subfield code="c">Johannes Ernesti, Peter Kaiser</subfield>
#     </datafield>
#     <datafield tag="250" ind1=" " ind2=" ">
#       <subfield code="a">7. Auflage, revidierte Ausgabe</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Bonn</subfield>
#       <subfield code="b">Rheinwerk</subfield>
#       <subfield code="b">Rheinwerk Computing</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">1080 Seiten</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="700" ind1="1" ind2=" ">
#       <subfield code="a">Kaiser, Peter</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>00644nam a22002058c 4500</leader>
#     <controlfield tag="001">991171113616005501</controlfield>
#     <controlfield tag="005">20221208230040.0</controlfield>
#     <controlfield tag="008">221021s2023    gw ||||| |||| 00||||ger  </controlfield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9783527718498</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">DE-101</subfield>
#       <subfield code="b">ger</subfield>
#       <subfield code="c">DE-101</subfield>
#       <subfield code="d">CH-ZuSLS BVERW BIG</subfield>
#       <subfield code="e">rda</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Hofmeister, Johannes C.</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Python fu&#776;r Dummies Alles-in-einem-Band</subfield>
#       <subfield code="c">Johannes C. Hofmeister, Horst Schneider</subfield>
#     </datafield>
#     <datafield tag="250" ind1=" " ind2=" ">
#       <subfield code="a">1. Auflage</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Weinheim</subfield>
#       <subfield code="b">Wiley-VCH</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">800 Seiten</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="490" ind1="0" ind2=" ">
#       <subfield code="a">... fu&#776;r Dummies</subfield>
#     </datafield>
#     <datafield tag="700" ind1="1" ind2=" ">
#       <subfield code="a">Schneider, Horst</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>01295nam a22003258c 4500</leader>
#     <controlfield tag="001">991171118031905501</controlfield>
#     <controlfield tag="005">20221222230033.0</controlfield>
#     <controlfield tag="008">221104s2023    mau           000 0 eng d</controlfield>
#     <datafield tag="015" ind1=" " ind2=" ">
#       <subfield code="a">GBC2K4879</subfield>
#       <subfield code="2">bnb</subfield>
#     </datafield>
#     <datafield tag="016" ind1="7" ind2=" ">
#       <subfield code="a">020807690</subfield>
#       <subfield code="2">Uk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9781098113551</subfield>
#       <subfield code="q">pbk.</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">1098113551</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(OCoLC)1351696745</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">UKMGB</subfield>
#       <subfield code="b">eng</subfield>
#       <subfield code="e">rda</subfield>
#       <subfield code="c">UKMGB</subfield>
#       <subfield code="d">OCLCF</subfield>
#       <subfield code="d">CH-ZuSLS UZB ZB</subfield>
#     </datafield>
#     <datafield tag="082" ind1="0" ind2="4">
#       <subfield code="a">005.133</subfield>
#       <subfield code="2">23</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Martelli, Alex</subfield>
#       <subfield code="1">https://isni.org/isni/0000000117696831.</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Python in a nutshell</subfield>
#     </datafield>
#     <datafield tag="250" ind1=" " ind2=" ">
#       <subfield code="a">Fourth edition /</subfield>
#       <subfield code="b">Alex Martelli, Anna Ravenscroft, Steve Holden, Paul McGuire</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Cambridge</subfield>
#       <subfield code="b">O'Reilly</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">1 volume</subfield>
#       <subfield code="c">23 cm</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="a">text</subfield>
#       <subfield code="2">rdacontent</subfield>
#       <subfield code="b">txt</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="a">unmediated</subfield>
#       <subfield code="2">rdamedia</subfield>
#       <subfield code="b">n</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="a">volume</subfield>
#       <subfield code="2">rdacarrier</subfield>
#       <subfield code="b">nc</subfield>
#     </datafield>
#     <datafield tag="500" ind1=" " ind2=" ">
#       <subfield code="a">Previous edition: published as by Alex Martelli, Anna Ravenscroft, Steve Holden. 2017</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Python (Computer program language)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Python (Computer program language)</subfield>
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst01084736</subfield>
#     </datafield>
#     <datafield tag="700" ind1="1" ind2=" ">
#       <subfield code="a">Ravenscroft, Anna Martelli</subfield>
#       <subfield code="1">https://isni.org/isni/0000000115677282.</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="700" ind1="1" ind2=" ">
#       <subfield code="a">Holden, Steve</subfield>
#       <subfield code="d">1950-</subfield>
#       <subfield code="1">https://isni.org/isni/0000000043127977.</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="700" ind1="1" ind2=" ">
#       <subfield code="a">McGuire, Paul</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="700" ind1="1" ind2="2">
#       <subfield code="a">Martelli, Alex.</subfield>
#       <subfield code="t">Python in a nutshell.</subfield>
#       <subfield code="s">Third edition.</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>00956nam a22003138c 4500</leader>
#     <controlfield tag="001">991171120270805501</controlfield>
#     <controlfield tag="005">20230103230039.0</controlfield>
#     <controlfield tag="008">221222s2023    mau           001 0 eng d</controlfield>
#     <datafield tag="015" ind1=" " ind2=" ">
#       <subfield code="a">GBC2K4887</subfield>
#       <subfield code="2">bnb</subfield>
#     </datafield>
#     <datafield tag="016" ind1="7" ind2=" ">
#       <subfield code="a">020807698</subfield>
#       <subfield code="2">Uk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9781098121228</subfield>
#       <subfield code="q">pbk.</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">1098121228</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(OCoLC)1355855878</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">S3O</subfield>
#       <subfield code="b">swe</subfield>
#       <subfield code="e">rda</subfield>
#       <subfield code="c">S3O</subfield>
#       <subfield code="d">CH-ZuSLS UZB ZB</subfield>
#     </datafield>
#     <datafield tag="082" ind1="0" ind2="4">
#       <subfield code="a">006.312</subfield>
#       <subfield code="2">23</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Vanderplas, Jacob T.</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Python data science handbook</subfield>
#       <subfield code="b">essential tools for working with data</subfield>
#       <subfield code="c">Jake VanderPlas</subfield>
#     </datafield>
#     <datafield tag="250" ind1=" " ind2=" ">
#       <subfield code="a">Second edition</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Cambridge</subfield>
#       <subfield code="b">O'Reilly</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">1 volume</subfield>
#       <subfield code="c">24 cm</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="500" ind1=" " ind2=" ">
#       <subfield code="a">Includes index</subfield>
#     </datafield>
#     <datafield tag="500" ind1=" " ind2=" ">
#       <subfield code="a">Previous edition: 2016</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Data mining</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Python (Computer program language)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Data mining</subfield>
#       <subfield code="2">fast</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Python (Computer program language)</subfield>
#       <subfield code="2">fast</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>02248nam a22003975c 4500</leader>
#     <controlfield tag="001">991171120406805501</controlfield>
#     <controlfield tag="005">20221223230045.0</controlfield>
#     <controlfield tag="008">220824s2023    flu      b    001 0 eng  </controlfield>
#     <datafield tag="010" ind1=" " ind2=" ">
#       <subfield code="a">  2022037925</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9781032211039</subfield>
#       <subfield code="q">hardback</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">1032211032</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9781003266730</subfield>
#       <subfield code="q">paperback</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">1003266738</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="z">9781032211053</subfield>
#       <subfield code="q">ebook</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(OCoLC)1345614137</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">DLC</subfield>
#       <subfield code="b">eng</subfield>
#       <subfield code="e">rda</subfield>
#       <subfield code="c">DLC</subfield>
#       <subfield code="d">CH-ZuSLS UBE</subfield>
#     </datafield>
#     <datafield tag="042" ind1=" " ind2=" ">
#       <subfield code="a">pcc</subfield>
#     </datafield>
#     <datafield tag="050" ind1="0" ind2="0">
#       <subfield code="a">HG6024.A3</subfield>
#       <subfield code="b">A455 2023</subfield>
#     </datafield>
#     <datafield tag="082" ind1="0" ind2="0">
#       <subfield code="a">332.64/57</subfield>
#       <subfield code="2">23/eng/20220923</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Al&#242;s, Elisa</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Introduction to financial derivatives with Python</subfield>
#       <subfield code="c">Elisa Al&#242;s, University of Barcelona, Spain, Ra&#250;l Merino, Pompeu Fabra University, Spain</subfield>
#     </datafield>
#     <datafield tag="263" ind1=" " ind2=" ">
#       <subfield code="a">2212</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Boca Raton</subfield>
#       <subfield code="b">Chapman &amp; Hall, CRC Press</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">pages cm.</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="490" ind1="0" ind2=" ">
#       <subfield code="a">Chapman &amp; Hall/CRC financial mathematics series</subfield>
#     </datafield>
#     <datafield tag="504" ind1=" " ind2=" ">
#       <subfield code="a">Includes bibliographical references and index</subfield>
#     </datafield>
# ...
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst00891019</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Python (Computer program language)</subfield>
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst01084736</subfield>
#     </datafield>
#     <datafield tag="700" ind1="1" ind2=" ">
#       <subfield code="a">Merino, Ra&#250;l</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="776" ind1="0" ind2="8">
#       <subfield code="i">Online version</subfield>
#       <subfield code="a">Al&#242;s, Elisa.</subfield>
#       <subfield code="t">Introduction to financial derivatives with Python</subfield>
#       <subfield code="d">Boca Raton : Chapman &amp; Hall, CRC Press, 2023</subfield>
#       <subfield code="z">9781032211053</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>01323naa a2200277 c 4500</leader>
#     <controlfield tag="001">991171130508305501</controlfield>
#     <controlfield tag="005">20230116162648.0</controlfield>
#     <controlfield tag="008">230116s2023    fr a|||g      000 | fre d</controlfield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">CH-ZuSLS HESSO HEPIA</subfield>
#       <subfield code="b">fre</subfield>
#       <subfield code="e">rda</subfield>
#     </datafield>
#     <datafield tag="082" ind1="7" ind2="4">
#       <subfield code="a">004</subfield>
#       <subfield code="2">23sdnb</subfield>
#     </datafield>
#     <datafield tag="245" ind1="0" ind2="0">
#       <subfield code="a">Python 3.11</subfield>
#       <subfield code="b">tour d'horizon des nouveaut&#233;s en pratique</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Colmar</subfield>
#       <subfield code="b">Editions Diamond</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">82 pages</subfield>
#       <subfield code="b">illustrations</subfield>
#       <subfield code="c">28 cm</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="505" ind1="2" ind2=" ">
#       <subfield code="a">Apprendre &#224; utiliser les modules de C++20 avec les compilateurs GCC 11 et Clang 14</subfield>
#     </datafield>
#     <datafield tag="505" ind1="2" ind2=" ">
#       <subfield code="a">Principes et limitations des corps de galois dans la g&#233;n&#233;ration de nombres pseudo-al&#233;atoires</subfield>
#     </datafield>
#     <datafield tag="505" ind1="2" ind2=" ">
#       <subfield code="a">D&#233;veloppez vos scripts sans avoir &#224; vous soucier des d&#233;pendances gr&#226;ce &#224; poetry</subfield>
#     </datafield>
#     <datafield tag="505" ind1="2" ind2=" ">
#       <subfield code="a">Cr&#233;ez une application graphique en combinant Chromium, Electron et le Framework react</subfield>
#     </datafield>
#     <datafield tag="505" ind1="2" ind2=" ">
#       <subfield code="a">D&#233;couvrez comment cr&#233;er vos propres ports freebsd et distribuer vos cr&#233;ations</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Informatique</subfield>
#       <subfield code="0">(IDREF)027234886</subfield>
#       <subfield code="2">idref</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Logiciels libres</subfield>
#       <subfield code="0">(IDREF)050678051</subfield>
#       <subfield code="2">idref</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Linux (logiciels)</subfield>
#       <subfield code="0">(IDREF)050773313</subfield>
#       <subfield code="2">idref</subfield>
#     </datafield>
#     <datafield tag="655" ind1=" " ind2="7">
#       <subfield code="a">Articles de p&#233;riodiques</subfield>
#       <subfield code="0">(IDREF)122706463</subfield>
#       <subfield code="2">idref</subfield>
#     </datafield>
#     <datafield tag="773" ind1="0" ind2=" ">
#       <subfield code="t">Linux magazine France</subfield>
#       <subfield code="g">no.261(2023:janv./f&#233;vr.)</subfield>
#       <subfield code="g">yr:2023</subfield>
#       <subfield code="g">no:261</subfield>
#       <subfield code="w">991120800849705501</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>02667nam a22004338c 4500</leader>
#     <controlfield tag="001">991171137585305501</controlfield>
#     <controlfield tag="005">20230201173616.0</controlfield>
#     <controlfield tag="008">221130s2023    flu      b    001 0 eng  </controlfield>
#     <datafield tag="010" ind1=" " ind2=" ">
#       <subfield code="a">  2022056310</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9781032377902</subfield>
#       <subfield code="q">hbk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">1032377909</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9781032378374</subfield>
#       <subfield code="q">pbk</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">1032378379</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="z">9781003342175</subfield>
#       <subfield code="q">ebk</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(OCoLC)1352989557</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">DLC</subfield>
#       <subfield code="b">ger</subfield>
#       <subfield code="e">rda</subfield>
#       <subfield code="c">DLC</subfield>
#       <subfield code="d">YDX</subfield>
#       <subfield code="d">CH-ZuSLS UZB ZB</subfield>
#     </datafield>
#     <datafield tag="042" ind1=" " ind2=" ">
#       <subfield code="a">pcc</subfield>
#     </datafield>
#     <datafield tag="050" ind1="0" ind2="0">
#       <subfield code="a">QA76.73.P98</subfield>
#       <subfield code="b">M383 2023</subfield>
#     </datafield>
#     <datafield tag="082" ind1="0" ind2="0">
#       <subfield code="a">005.13/3</subfield>
#       <subfield code="2">23/eng/20221202</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Mattingly, William J. B.</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Introduction to Python for humanists</subfield>
#       <subfield code="c">William J.B. Mattingly</subfield>
#     </datafield>
#     <datafield tag="250" ind1=" " ind2=" ">
#       <subfield code="a">First edition</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Boca Raton</subfield>
#       <subfield code="b">CRC Press</subfield>
#       <subfield code="c">[2023]</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">pages cm.</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="490" ind1="0" ind2=" ">
#       <subfield code="a">Chapman &amp; Hall/CRC the Python series</subfield>
#     </datafield>
#     <datafield tag="504" ind1=" " ind2=" ">
#       <subfield code="a">Includes bibliographical references and index</subfield>
#     </datafield>
#     <datafield tag="520" ind1=" " ind2=" ">
#       <subfield code="a">"This book will introduce digital humanists at all levels of education to Python. It provides background and guidance on learning the Python computer programming language, and as it presumes no knowledge on the part of the reader about computers or coding concepts allows the reader to gradually learn the more complex tasks that are currently popular in the field of digital humanities. This book will be aimed at undergraduates, graduates, and faculty who are interested in learning how to use Python as a tool within their workflow. An Introduction to Python for Digital Humanists will act as a primer for students who wish to use Python, allowing them to engage with more advanced textbooks. This book fills a real need, as it is first Python introduction to be aimed squarely at humanities students, as other books currently available do not approach Python from a humanities perspective. It will be designed so that those experienced in Python can teach from it, in addition to allowing those who are interested in being self-taught can use it for that purpose"--</subfield>
#       <subfield code="c">Provided by publisher.</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Python (Computer program language)</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Engineering</subfield>
#       <subfield code="x">Data processing</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Science</subfield>
#       <subfield code="x">Data processing</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="0">
#       <subfield code="a">Computer programming</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Computer programming</subfield>
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst00872390</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Engineering</subfield>
#       <subfield code="x">Data processing</subfield>
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst00910334</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Python (Computer program language)</subfield>
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst01084736</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="7">
#       <subfield code="a">Science</subfield>
#       <subfield code="x">Data processing</subfield>
#       <subfield code="2">fast</subfield>
#       <subfield code="0">(OCoLC)fst01108207</subfield>
#     </datafield>
#     <datafield tag="776" ind1="0" ind2="8">
#       <subfield code="i">Online version</subfield>
#       <subfield code="a">Mattingly, William J. B.</subfield>
#       <subfield code="t">Introduction to Python for humanists</subfield>
#       <subfield code="b">First edition</subfield>
#       <subfield code="d">Boca Raton : CRC Press, 2023</subfield>
#       <subfield code="z">9781003342175</subfield>
#     </datafield>
#   </record>
#   <record>
#     <leader>01607nam a22004457c 4500</leader>
#     <controlfield tag="001">991171141888005501</controlfield>
#     <controlfield tag="005">20230208123543.0</controlfield>
#     <controlfield tag="008">230131s2023    xx            000 0 eng d</controlfield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">9783031176456</subfield>
#     </datafield>
#     <datafield tag="020" ind1=" " ind2=" ">
#       <subfield code="a">3031176456</subfield>
#     </datafield>
#     <datafield tag="035" ind1=" " ind2=" ">
#       <subfield code="a">(OCoLC)1367228661</subfield>
#     </datafield>
#     <datafield tag="040" ind1=" " ind2=" ">
#       <subfield code="a">GBVCP</subfield>
#       <subfield code="b">ger</subfield>
#       <subfield code="e">rda</subfield>
#       <subfield code="d">CH-ZuSLS ETH</subfield>
#     </datafield>
#     <datafield tag="082" ind1="0" ind2="4">
#       <subfield code="a">005.133</subfield>
#     </datafield>
#     <datafield tag="100" ind1="1" ind2=" ">
#       <subfield code="a">Wang, Jay</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#     <datafield tag="245" ind1="1" ind2="0">
#       <subfield code="a">Introduction to computation in physical sciences</subfield>
#       <subfield code="b">interactive computing and visualization with Python (TM)</subfield>
#       <subfield code="c">Jay Wang, Adam Wang</subfield>
#     </datafield>
#     <datafield tag="264" ind1=" " ind2="1">
#       <subfield code="a">Cham</subfield>
#       <subfield code="b">Springer</subfield>
#       <subfield code="c">2023</subfield>
#     </datafield>
#     <datafield tag="300" ind1=" " ind2=" ">
#       <subfield code="a">255 Seiten</subfield>
#     </datafield>
#     <datafield tag="336" ind1=" " ind2=" ">
#       <subfield code="b">txt</subfield>
#       <subfield code="2">rdacontent</subfield>
#     </datafield>
#     <datafield tag="337" ind1=" " ind2=" ">
#       <subfield code="b">n</subfield>
#       <subfield code="2">rdamedia</subfield>
#     </datafield>
#     <datafield tag="338" ind1=" " ind2=" ">
#       <subfield code="b">nc</subfield>
#       <subfield code="2">rdacarrier</subfield>
#     </datafield>
#     <datafield tag="490" ind1="0" ind2=" ">
#       <subfield code="a">Synthesis Lectures on Computation and Analytics</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">COMPUTERS / Computer Science</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">COMPUTERS / Data Processing / General</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">COMPUTERS / Programming / General</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">COMPUTERS / Programming Languages / Python</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Combinatorics &amp; graph theory</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Computer programming / software development</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Computerprogrammierung und Softwareentwicklung</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Informationsvisualisierung</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">MATHEMATICS / Graphic Methods</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Mathematical physics</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Mathematical theory of computation</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Mathematik f&#252;r Informatiker</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Mathematische Physik</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Maths for scientists</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Numerische Mathematik</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Programmier- und Skriptsprachen, allgemein</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">Programming &amp; scripting languages: general</subfield>
#     </datafield>
#     <datafield tag="650" ind1=" " ind2="4">
#       <subfield code="a">SCIENCE / Mathematical Physics</subfield>
#     </datafield>
#     <datafield tag="700" ind1="1" ind2=" ">
#       <subfield code="a">Wang, Adam</subfield>
#       <subfield code="4">aut</subfield>
#     </datafield>
#   </record>
# </collection>

# %%
# Get the tag of the element
xml.tag
# Out:
# 'collection'

# %%
# get the 5th record
xml[4]
# Out:
# <Element record at 0x7fe670650640>

# %%
# Get all the records in a list
records = xml.findall('record')
records
# Out:
# [<Element record at 0x7fe67062d340>,
#  <Element record at 0x7fe6705629c0>,
#  <Element record at 0x7fe670562840>,
#  <Element record at 0x7fe670562680>,
#  <Element record at 0x7fe670650640>,
#  <Element record at 0x7fe670562540>,
#  <Element record at 0x7fe670562c00>,
#  <Element record at 0x7fe670562800>,
#  <Element record at 0x7fe670562880>,
#  <Element record at 0x7fe670562b00>,
#  <Element record at 0x7fe6706b1f00>,
#  <Element record at 0x7fe670562b40>,
#  <Element record at 0x7fe670562bc0>,
#  <Element record at 0x7fe670562cc0>,
#  <Element record at 0x7fe670562b80>]

# %%
# Get 6th field of 4th record
records[3][5]
# Out:
# <Element datafield at 0x7fe67065dac0>

# %%
# Use find to get the first matching element => good in this case each record has only one controlfield 001
for record in records:
    print(record.find('controlfield[@tag="001"]').text)
# Out:
# 991171012127005501
# 991171016129705501
# 991171021422205501
# 991171033010205501
# 991171056243005501
# 991171104173205501
# 991171105403405501
# 991171113493405501
# 991171113616005501
# 991171118031905501
# 991171120270805501
# 991171120406805501
# 991171130508305501
# 991171137585305501
# 991171141888005501

# %%
# Use findall to get a list of all matching elements
for record in records:
    datafields = record.findall('datafield')
    for datafield in datafields:
        # Use get to get an attribute value
        print('Tag: ', datafield.get('tag'))
        
        # to change an attribute, two possibilities
        datafield.set('ind1', '1')
        datafield.attrib['ind2'] = '3'
        
        # Use attr to get all atributes as dictionary
        print('All attributes: ', datafield.attrib)
# Out:
# Tag:  015
# All attributes:  {'tag': '015', 'ind1': '1', 'ind2': '3'}
# Tag:  016
# All attributes:  {'tag': '016', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  044
# All attributes:  {'tag': '044', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  504
# All attributes:  {'tag': '504', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  776
# All attributes:  {'tag': '776', 'ind1': '1', 'ind2': '3'}
# Tag:  776
# All attributes:  {'tag': '776', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  250
# All attributes:  {'tag': '250', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  490
# All attributes:  {'tag': '490', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  700
# All attributes:  {'tag': '700', 'ind1': '1', 'ind2': '3'}
# Tag:  015
# All attributes:  {'tag': '015', 'ind1': '1', 'ind2': '3'}
# Tag:  016
# All attributes:  {'tag': '016', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  084
# All attributes:  {'tag': '084', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  250
# All attributes:  {'tag': '250', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  655
# All attributes:  {'tag': '655', 'ind1': '1', 'ind2': '3'}
# Tag:  900
# All attributes:  {'tag': '900', 'ind1': '1', 'ind2': '3'}
# Tag:  900
# All attributes:  {'tag': '900', 'ind1': '1', 'ind2': '3'}
# Tag:  010
# All attributes:  {'tag': '010', 'ind1': '1', 'ind2': '3'}
# Tag:  015
# All attributes:  {'tag': '015', 'ind1': '1', 'ind2': '3'}
# Tag:  016
# All attributes:  {'tag': '016', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  042
# All attributes:  {'tag': '042', 'ind1': '1', 'ind2': '3'}
# Tag:  050
# All attributes:  {'tag': '050', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  250
# All attributes:  {'tag': '250', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  500
# All attributes:  {'tag': '500', 'ind1': '1', 'ind2': '3'}
# Tag:  504
# All attributes:  {'tag': '504', 'ind1': '1', 'ind2': '3'}
# Tag:  520
# All attributes:  {'tag': '520', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  700
# All attributes:  {'tag': '700', 'ind1': '1', 'ind2': '3'}
# Tag:  776
# All attributes:  {'tag': '776', 'ind1': '1', 'ind2': '3'}
# Tag:  776
# All attributes:  {'tag': '776', 'ind1': '1', 'ind2': '3'}
# Tag:  776
# All attributes:  {'tag': '776', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  490
# All attributes:  {'tag': '490', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  655
# All attributes:  {'tag': '655', 'ind1': '1', 'ind2': '3'}
# Tag:  010
# All attributes:  {'tag': '010', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  042
# All attributes:  {'tag': '042', 'ind1': '1', 'ind2': '3'}
# Tag:  050
# All attributes:  {'tag': '050', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  250
# All attributes:  {'tag': '250', 'ind1': '1', 'ind2': '3'}
# Tag:  263
# All attributes:  {'tag': '263', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  490
# All attributes:  {'tag': '490', 'ind1': '1', 'ind2': '3'}
# Tag:  504
# All attributes:  {'tag': '504', 'ind1': '1', 'ind2': '3'}
# Tag:  520
# All attributes:  {'tag': '520', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  776
# All attributes:  {'tag': '776', 'ind1': '1', 'ind2': '3'}
# Tag:  015
# All attributes:  {'tag': '015', 'ind1': '1', 'ind2': '3'}
# Tag:  016
# All attributes:  {'tag': '016', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  250
# All attributes:  {'tag': '250', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  500
# All attributes:  {'tag': '500', 'ind1': '1', 'ind2': '3'}
# Tag:  500
# All attributes:  {'tag': '500', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  015
# All attributes:  {'tag': '015', 'ind1': '1', 'ind2': '3'}
# Tag:  016
# All attributes:  {'tag': '016', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  250
# All attributes:  {'tag': '250', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  700
# All attributes:  {'tag': '700', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  250
# All attributes:  {'tag': '250', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  490
# All attributes:  {'tag': '490', 'ind1': '1', 'ind2': '3'}
# Tag:  700
# All attributes:  {'tag': '700', 'ind1': '1', 'ind2': '3'}
# Tag:  015
# All attributes:  {'tag': '015', 'ind1': '1', 'ind2': '3'}
# Tag:  016
# All attributes:  {'tag': '016', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  250
# All attributes:  {'tag': '250', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  500
# All attributes:  {'tag': '500', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  700
# All attributes:  {'tag': '700', 'ind1': '1', 'ind2': '3'}
# Tag:  700
# All attributes:  {'tag': '700', 'ind1': '1', 'ind2': '3'}
# Tag:  700
# All attributes:  {'tag': '700', 'ind1': '1', 'ind2': '3'}
# Tag:  700
# All attributes:  {'tag': '700', 'ind1': '1', 'ind2': '3'}
# Tag:  015
# All attributes:  {'tag': '015', 'ind1': '1', 'ind2': '3'}
# Tag:  016
# All attributes:  {'tag': '016', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  250
# All attributes:  {'tag': '250', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  500
# All attributes:  {'tag': '500', 'ind1': '1', 'ind2': '3'}
# Tag:  500
# All attributes:  {'tag': '500', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  010
# All attributes:  {'tag': '010', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  042
# All attributes:  {'tag': '042', 'ind1': '1', 'ind2': '3'}
# Tag:  050
# All attributes:  {'tag': '050', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  263
# All attributes:  {'tag': '263', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  490
# All attributes:  {'tag': '490', 'ind1': '1', 'ind2': '3'}
# Tag:  504
# All attributes:  {'tag': '504', 'ind1': '1', 'ind2': '3'}
# Tag:  520
# All attributes:  {'tag': '520', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  700
# All attributes:  {'tag': '700', 'ind1': '1', 'ind2': '3'}
# Tag:  776
# All attributes:  {'tag': '776', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  505
# All attributes:  {'tag': '505', 'ind1': '1', 'ind2': '3'}
# Tag:  505
# All attributes:  {'tag': '505', 'ind1': '1', 'ind2': '3'}
# Tag:  505
# All attributes:  {'tag': '505', 'ind1': '1', 'ind2': '3'}
# Tag:  505
# All attributes:  {'tag': '505', 'ind1': '1', 'ind2': '3'}
# Tag:  505
# All attributes:  {'tag': '505', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  655
# All attributes:  {'tag': '655', 'ind1': '1', 'ind2': '3'}
# Tag:  773
# All attributes:  {'tag': '773', 'ind1': '1', 'ind2': '3'}
# Tag:  010
# All attributes:  {'tag': '010', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  042
# All attributes:  {'tag': '042', 'ind1': '1', 'ind2': '3'}
# Tag:  050
# All attributes:  {'tag': '050', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  250
# All attributes:  {'tag': '250', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  490
# All attributes:  {'tag': '490', 'ind1': '1', 'ind2': '3'}
# Tag:  504
# All attributes:  {'tag': '504', 'ind1': '1', 'ind2': '3'}
# Tag:  520
# All attributes:  {'tag': '520', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  776
# All attributes:  {'tag': '776', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  020
# All attributes:  {'tag': '020', 'ind1': '1', 'ind2': '3'}
# Tag:  035
# All attributes:  {'tag': '035', 'ind1': '1', 'ind2': '3'}
# Tag:  040
# All attributes:  {'tag': '040', 'ind1': '1', 'ind2': '3'}
# Tag:  082
# All attributes:  {'tag': '082', 'ind1': '1', 'ind2': '3'}
# Tag:  100
# All attributes:  {'tag': '100', 'ind1': '1', 'ind2': '3'}
# Tag:  245
# All attributes:  {'tag': '245', 'ind1': '1', 'ind2': '3'}
# Tag:  264
# All attributes:  {'tag': '264', 'ind1': '1', 'ind2': '3'}
# Tag:  300
# All attributes:  {'tag': '300', 'ind1': '1', 'ind2': '3'}
# Tag:  336
# All attributes:  {'tag': '336', 'ind1': '1', 'ind2': '3'}
# Tag:  337
# All attributes:  {'tag': '337', 'ind1': '1', 'ind2': '3'}
# Tag:  338
# All attributes:  {'tag': '338', 'ind1': '1', 'ind2': '3'}
# Tag:  490
# All attributes:  {'tag': '490', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  650
# All attributes:  {'tag': '650', 'ind1': '1', 'ind2': '3'}
# Tag:  700
# All attributes:  {'tag': '700', 'ind1': '1', 'ind2': '3'}

# %%
for record in records:
    # ".//" means that we look for a field in all children elements (not only direct children)
    print(record.find('.//subfield').text)
# Out:
# 22,N20
# 9783527719952
# GBC244409
#   2022004761
# 9783031137136
#   2022026521
# GBC2K0036
# 22,N47
# 9783527718498
# GBC2K4879
# GBC2K4887
#   2022037925
# CH-ZuSLS HESSO HEPIA
#   2022056310
# 9783031176456

# %%
# Create a new node
new_field = etree.XML('''<datafield tag="500" ind1=" " ind2=" ">
                             <subfield code="a">TEST</subfield>
                         </datafield>''')
new_field
# Out:
# <Element datafield at 0x7fe670649080>

# %%
print(etree.tostring(new_field, pretty_print=True).decode())
# Out:
# <datafield tag="500" ind1=" " ind2=" ">
#                              <subfield code="a">TEST</subfield>
#                          </datafield>

# %%
for record in records:
    # Important to not add the same node several times => use deepcopy or create several times the node
    new_copy = deepcopy(new_field)
    
    # Use append to add the field at the last child
    record.append(new_copy)
    
    # Use this line to sort fields / please do not sort automatic subfields => order of subfields matters!
    record[:] = sorted(record, key=lambda field_or_contr: field_or_contr.get('tag', '000'))

# %%
print(etree.tostring(records[2], pretty_print=True).decode())
# Out:
# <record>
#   <leader>01550nam a2200409 c 4500</leader>
#   <controlfield tag="001">991171021422205501</controlfield>
#   <controlfield tag="005">20230201101208.0</controlfield>
#   <controlfield tag="008">220307s2023    xxk           000 0 eng d</controlfield>
#   <datafield tag="015" ind1="1" ind2="3">
#     <subfield code="a">GBC244409</subfield>
#     <subfield code="2">bnb</subfield>
#   </datafield>
#   <datafield tag="016" ind1="1" ind2="3">
#     <subfield code="a">020518196</subfield>
#     <subfield code="2">Uk</subfield>
#   </datafield>
#   <datafield tag="020" ind1="1" ind2="3">
#     <subfield code="a">9781292424125</subfield>
#     <subfield code="q">pbk.</subfield>
#   </datafield>
#   <datafield tag="020" ind1="1" ind2="3">
#     <subfield code="a">1292424125</subfield>
#   </datafield>
#   <datafield tag="035" ind1="1" ind2="3">
#     <subfield code="a">(OCoLC)1308489142</subfield>
#   </datafield>
#   <datafield tag="040" ind1="1" ind2="3">
#     <subfield code="a">UKMGB</subfield>
#     <subfield code="b">ger</subfield>
#     <subfield code="e">rda</subfield>
#     <subfield code="c">UKMGB</subfield>
#     <subfield code="d">OCLCO</subfield>
#     <subfield code="d">CH-ZuSLS UZB ZB</subfield>
#   </datafield>
#   <datafield tag="082" ind1="1" ind2="3">
#     <subfield code="a">004</subfield>
#     <subfield code="2">23sdnb</subfield>
#   </datafield>
#   <datafield tag="082" ind1="1" ind2="3">
#     <subfield code="a">005.133</subfield>
#     <subfield code="2">23</subfield>
#   </datafield>
#   <datafield tag="084" ind1="1" ind2="3">
#     <subfield code="a">ST 250</subfield>
#     <subfield code="2">rvk</subfield>
#   </datafield>
#   <datafield tag="100" ind1="1" ind2="3">
#     <subfield code="a">Liang, Y. Daniel</subfield>
#     <subfield code="4">aut</subfield>
#     <subfield code="0">(DE-588)1235702677</subfield>
#   </datafield>
#   <datafield tag="245" ind1="1" ind2="3">
#     <subfield code="a">Introduction to Python programming and data structures</subfield>
#     <subfield code="c">Y. Daniel Liang</subfield>
#   </datafield>
#   <datafield tag="250" ind1="1" ind2="3">
#     <subfield code="a">Third edition, global edition</subfield>
#   </datafield>
#   <datafield tag="264" ind1="1" ind2="3">
#     <subfield code="a">Harlow, United Kingdom</subfield>
#     <subfield code="b">Pearson</subfield>
#     <subfield code="c">[2023]</subfield>
#   </datafield>
#   <datafield tag="300" ind1="1" ind2="3">
#     <subfield code="a">797 Seiten</subfield>
#     <subfield code="b">Illustrationen</subfield>
#   </datafield>
#   <datafield tag="336" ind1="1" ind2="3">
#     <subfield code="b">txt</subfield>
#     <subfield code="2">rdacontent</subfield>
#   </datafield>
#   <datafield tag="337" ind1="1" ind2="3">
#     <subfield code="b">n</subfield>
#     <subfield code="2">rdamedia</subfield>
#   </datafield>
#   <datafield tag="338" ind1="1" ind2="3">
#     <subfield code="b">nc</subfield>
#     <subfield code="2">rdacarrier</subfield>
#   </datafield>
#   <datafield tag="500" ind1=" " ind2=" ">
#                              <subfield code="a">TEST</subfield>
#                          </datafield>
#   <datafield tag="650" ind1="1" ind2="3">
#     <subfield code="a">Python (Computer program language)</subfield>
#   </datafield>
#   <datafield tag="650" ind1="1" ind2="3">
#     <subfield code="a">Object-oriented programming (Computer science)</subfield>
#   </datafield>
#   <datafield tag="650" ind1="1" ind2="3">
#     <subfield code="a">Python (Langage de programmation)</subfield>
#   </datafield>
#   <datafield tag="650" ind1="1" ind2="3">
#     <subfield code="a">Programmation oriente&#769;e objet (Informatique)</subfield>
#   </datafield>
#   <datafield tag="650" ind1="1" ind2="3">
#     <subfield code="a">Object-oriented programming (Computer science)</subfield>
#     <subfield code="2">fast</subfield>
#     <subfield code="0">(OCoLC)fst01042804</subfield>
#   </datafield>
#   <datafield tag="650" ind1="1" ind2="3">
#     <subfield code="a">Python (Computer program language)</subfield>
#     <subfield code="2">fast</subfield>
#     <subfield code="0">(OCoLC)fst01084736</subfield>
#   </datafield>
#   <datafield tag="650" ind1="1" ind2="3">
#     <subfield code="a">Python</subfield>
#     <subfield code="g">Programmiersprache</subfield>
#     <subfield code="2">gnd</subfield>
#     <subfield code="0">(DE-588)4434275-5</subfield>
#   </datafield>
#   <datafield tag="650" ind1="1" ind2="3">
#     <subfield code="a">Objektorientierte Programmierung</subfield>
#     <subfield code="2">gnd</subfield>
#     <subfield code="0">(DE-588)4233947-9</subfield>
#   </datafield>
#   <datafield tag="650" ind1="1" ind2="3">
#     <subfield code="a">Datenstruktur</subfield>
#     <subfield code="2">gnd</subfield>
#     <subfield code="0">(DE-588)4011146-5</subfield>
#   </datafield>
#   <datafield tag="655" ind1="1" ind2="3">
#     <subfield code="a">Lehrbuch</subfield>
#     <subfield code="2">gnd-content</subfield>
#   </datafield>
#   <datafield tag="900" ind1="1" ind2="3">
#     <subfield code="a">OK_GND</subfield>
#     <subfield code="x">UZB/Z01/202212/tschu</subfield>
#   </datafield>
#   <datafield tag="900" ind1="1" ind2="3">
#     <subfield code="a">Stoppsignal FRED</subfield>
#     <subfield code="x">UZB/Z01/202212</subfield>
#   </datafield>
# </record>
